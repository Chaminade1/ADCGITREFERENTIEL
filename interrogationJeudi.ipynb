# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaminade1/ADCGITREFERENTIEL/blob/main/interrogationJeudi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


# Création de 2 dataframe de valeur de 1 à 10
df = pd.DataFrame({'X': np.random.rand(10),
                   'Y': np.random.rand(10)})

# Afficher le DataFrame
print(df)

# Tracer un graphique en ligne (line plot) en utilisant les valeurs des colonnes 'X' et 'Y' comme données
df.plot(kind='line')
# Out:
#           X         Y
# 0  0.510946  0.288242
# 1  0.499941  0.873089
# 2  0.534208  0.168386
# 3  0.964205  0.765621
# 4  0.995554  0.363924
# 5  0.149570  0.662899
# 6  0.160021  0.919588
# 7  0.819808  0.692160
# 8  0.586365  0.152606
# 9  0.481285  0.466044
# <Axes: >
